# %% [markdown]
# # LSDB Commisioning Project 4: Find RRLyrae variables in ComCam data

# %% [markdown]
# ## Installation

# %%
# %pip install lsdb astropy light_curve --quiet
# Out:
# WARNING: Error parsing dependencies of lsst-analysis-ap: Invalid version: 'g7299995a7b+1f1e76cba2'
# WARNING: Error parsing dependencies of lsst-display-astrowidgets: Invalid version: 'g07dc498a13+5a531fccd6'
# WARNING: Error parsing dependencies of lsst-drp-pipe: Invalid version: 'gf7e4a6c30e+4ea55e0f71'
# WARNING: Error parsing dependencies of lsst-atmospec: Invalid version: 'ge49103809e+e7de43a99e'
# WARNING: Error parsing dependencies of lsst-cp-verify: Invalid version: 'g61791e16cc+7250cc7781'
# WARNING: Error parsing dependencies of lsst-faro: Invalid version: 'ge0f627f07d+7add1e4b5a'
# WARNING: Error parsing dependencies of lsst-fgcmcal: Invalid version: 'gfe7187db8c+55cd7d2043'
# WARNING: Error parsing dependencies of lsst-display-matplotlib: Invalid version: 'gaaedd4e678+5a531fccd6'
# WARNING: Error parsing dependencies of lsst-display-firefly: Invalid version: 'g1a7e361dbc+5a531fccd6'
# WARNING: Error parsing dependencies of lsst-ap-verify: Invalid version: 'ge9aa7caa0f+b1cbfe56db'
# WARNING: Error parsing dependencies of lsst-jointcal: Invalid version: 'gde0f65d7ad+a0ab96d407'
# WARNING: Error parsing dependencies of lsst-cbp: Invalid version: 'g7a6b8c32e4+5a531fccd6'
# WARNING: Error parsing dependencies of lsst-obs-fiberspectrograph: Invalid version: 'g7c748bb4b1+127e7c8e43'
# WARNING: Error parsing dependencies of lsst-obs-rubingenericcamera: Invalid version: 'gd9c630d0fb+127e7c8e43'
# WARNING: Error parsing dependencies of lsst-obs-cfht: Invalid version: 'g8219804093+d85ac13a7a'
# WARNING: Error parsing dependencies of lsst-multiprofit: Invalid version: 'gdffc94211f+56c01e7dfc'
# WARNING: Error parsing dependencies of lsst-rucio-register: Invalid version: 'g13a924b9ab+2afc2f6806'
# WARNING: Error parsing dependencies of lsst-ctrl-bps-parsl: Invalid version: 'gd4d39448cb+bdcc1c454b'
# WARNING: Error parsing dependencies of lsst-ctrl-bps-panda: Invalid version: 'g455135ae9e+bdcc1c454b'
# WARNING: Error parsing dependencies of lsst-lsst-bps-plugins: Invalid version: 'g7de033f5be+133675ff0d'
# WARNING: Error parsing dependencies of lsst-ctrl-platform-s3df: Invalid version: 'gc02a8624fe+14e9ab1557'
# WARNING: Error parsing dependencies of lsst-ctrl-bps: Invalid version: 'g166633b946+d00315b3e4'
# WARNING: Error parsing dependencies of lsst-ctrl-bps-htcondor: Invalid version: 'g0242b1529e+bdcc1c454b'
# WARNING: Error parsing dependencies of lsst-ctrl-execute: Invalid version: 'gb189883cd2+b6d6e11ea9'
# WARNING: Error parsing dependencies of lsst-display-ds9: Invalid version: 'g1409bbee79+5a531fccd6'
# WARNING: Error parsing dependencies of lsst-meas-extensions-simpleshape: Invalid version: 'gcf25f946ba+749e2df9f6'
# WARNING: Error parsing dependencies of lsst-meas-transinet: Invalid version: 'gd42b450c19+749e2df9f6'
# WARNING: Error parsing dependencies of lsst-source-injection: Invalid version: 'g2b6d51bd51+7250cc7781'
# WARNING: Error parsing dependencies of lsst-cell-coadds: Invalid version: 'gc191eedf9b+1d672c3699'
# WARNING: Error parsing dependencies of lsst-drp-tasks: Invalid version: 'g6b83ee0694+6e4325f56b'
# WARNING: Error parsing dependencies of lsst-obs-lsst: Invalid version: 'ge51df1da54+c213d7824a'
# WARNING: Error parsing dependencies of lsst-ctrl-mpexec: Invalid version: 'g1832a0e297+4c45d8ecef'
# WARNING: Error parsing dependencies of lsst-obs-decam: Invalid version: 'g3bd4b5ce2c+753c3426d3'
# WARNING: Error parsing dependencies of lsst-obs-subaru: Invalid version: 'g73b83bc68c+898e789c27'
# WARNING: Error parsing dependencies of lsst-cp-pipe: Invalid version: 'g235520fa62+95b0a6f15c'
# WARNING: Error parsing dependencies of lsst-analysis-tools: Invalid version: 'g4d1c935b43+65f7c74f5f'
# WARNING: Error parsing dependencies of lsst-ap-association: Invalid version: 'g49a9c4a1ce+da39fb88cb'
# WARNING: Error parsing dependencies of lsst-ap-pipe: Invalid version: 'g34aa6b7697+93a3124002'
# WARNING: Error parsing dependencies of lsst-scarlet-lite: Invalid version: 'gf58bf46354+e55fef2c71'
# WARNING: Error parsing dependencies of lsst-meas-extensions-scarlet: Invalid version: 'g4381c4bf55+f6c9f939b6'
# WARNING: Error parsing dependencies of lsst-meas-extensions-psfex: Invalid version: 'g28da252d5a+b6acab2954'
# WARNING: Error parsing dependencies of lsst-meas-extensions-piff: Invalid version: 'geab183fbe5+f9e43d3906'
# WARNING: Error parsing dependencies of lsst-meas-extensions-gaap: Invalid version: 'ga95acd0462+0099053dd6'
# WARNING: Error parsing dependencies of lsst-meas-extensions-photometrykron: Invalid version: 'g60b5630c4e+f9e43d3906'
# WARNING: Error parsing dependencies of lsst-meas-extensions-convolved: Invalid version: 'g7da95dfc27+c4e5ede062'
# WARNING: Error parsing dependencies of lsst-ip-isr: Invalid version: 'gc2fcbed0ba+f9e43d3906'
# WARNING: Error parsing dependencies of lsst-verify-metrics: Invalid version: 'g05f563eca1+e55fef2c71'
# WARNING: Error parsing dependencies of lsst-sdm-schemas: Invalid version: 'g01af07b095+e55fef2c71'
# WARNING: Error parsing dependencies of lsst-felis: Invalid version: 'g40a360a34f+120a1557b7'
# WARNING: Error parsing dependencies of lsst-dax-apdb: Invalid version: 'g43bc871e57+32b9ddb877'
# WARNING: Error parsing dependencies of lsst-verify: Invalid version: 'gec3c2e1fae+c509b6e807'
# WARNING: Error parsing dependencies of lsst-meas-extensions-shapehsm: Invalid version: 'g4664cc73e2+f9e43d3906'
# WARNING: Error parsing dependencies of lsst-meas-extensions-trailedsources: Invalid version: 'g33399d78f5+749e2df9f6'
# WARNING: Error parsing dependencies of lsst-meas-astrom: Invalid version: 'g8b49a6ea8e+f9e43d3906'
# WARNING: Error parsing dependencies of lsst-ip-diffim: Invalid version: 'gb092a606b0+a33ed67792'
# WARNING: Error parsing dependencies of lsst-coadd-utils: Invalid version: 'g89139ef638+5a531fccd6'
# WARNING: Error parsing dependencies of lsst-pipe-tasks: Invalid version: 'g3d4cdeeb7c+495e717508'
# WARNING: Error parsing dependencies of lsst-shapelet: Invalid version: 'g989de1cb63+5a531fccd6'
# WARNING: Error parsing dependencies of lsst-meas-modelfit: Invalid version: 'g9f33ca652e+c963d5c8aa'
# WARNING: Error parsing dependencies of astro-metadata-translator: Invalid version: 'g1e2c377723+af2545e932'
# WARNING: Error parsing dependencies of lsst-obs-base: Invalid version: 'g08a13b53f0+c36e5035f1'
# WARNING: Error parsing dependencies of lsst-pipe-base: Invalid version: 'g98653113c0+0c3c8079bf'
# WARNING: Error parsing dependencies of lsst-daf-relation: Invalid version: 'g46a8c529b8+25667260f6'
# WARNING: Error parsing dependencies of lsst-resources: Invalid version: 'gc62a4ab5da+25667260f6'
# WARNING: Error parsing dependencies of lsst-daf-butler: Invalid version: 'g6259bf8f88+49d5bde2b1'
# WARNING: Error parsing dependencies of lsst-skymap: Invalid version: 'g1fd858c14a+bae9e05889'
# WARNING: Error parsing dependencies of lsst-meas-base: Invalid version: 'g9a9baf55bd+f1bd1a7c26'
# WARNING: Error parsing dependencies of lsst-meas-algorithms: Invalid version: 'g6e5c4a0e23+f441d97430'
# WARNING: Error parsing dependencies of astshim: Invalid version: 'g78460c75b0+8427c4cc8f'
# WARNING: Error parsing dependencies of lsst-log: Invalid version: 'ge278dab8ac+25667260f6'
# WARNING: Error parsing dependencies of lsst-sphgeom: Invalid version: 'gca43fec769+e55fef2c71'
# WARNING: Error parsing dependencies of lsst-geom: Invalid version: 'gd6cbbdb0b4+784e334a77'
# WARNING: Error parsing dependencies of lsst-pex-config: Invalid version: 'g8534526c7b+af2545e932'
# WARNING: Error parsing dependencies of lsst-pex-exceptions: Invalid version: 'g786e29fd12+307f82e6af'
# WARNING: Error parsing dependencies of lsst-base: Invalid version: 'g53246c7159+e55fef2c71'
# WARNING: Error parsing dependencies of lsst-cpputils: Invalid version: 'gabe3b4be73+9c0c3c7524'
# WARNING: Error parsing dependencies of lsst-sconsutils: Invalid version: 'g1ca295d4bc'
# WARNING: Error parsing dependencies of lsst-utils: Invalid version: 'gbd976da7f8+e55fef2c71'
# WARNING: Error parsing dependencies of lsst-daf-base: Invalid version: 'gecb8035dfe+0fa5abcb94'
# WARNING: Error parsing dependencies of lsst-afw: Invalid version: 'gefa07fa684+89734069dd'
# WARNING: Error parsing dependencies of lsst-meas-deblender: Invalid version: 'g85d8d04dbe+ded3a614ca'
# Note: you may need to restart the kernel to use updated packages.

# %%
import lsdb
lsdb.__version__
# Out:
# '0.4.4'

# %%
# Relevant Directories
#ls /sdf/scratch/users/n/ncaplar/HATS

comcam_obj = "/sdf/data/rubin/shared/lsdb_commissioning/Object_50"
comcam_src = "/sdf/data/rubin/shared/lsdb_commissioning/forcedSource_50"
comcam_diasrc = "/sdf/data/rubin/shared/lsdb_commissioning/diaSource_50"
comcam_srcmjd = "/sdf/data/rubin/shared/lsdb_commissioning/forcedSource_50_with_mjd"

# %% [markdown]
# ## Loading ComCam Data into LSDB

# %%
from dask.distributed import Client

# Start with a small client
client = Client(n_workers=24, memory_limit="3GB", threads_per_worker=1)
client
# Out:
# <Client: 'tcp://127.0.0.1:14005' processes=24 threads=24, memory=67.06 GiB>
# WARNING:distributed.shuffle._scheduler_plugin:Shuffle 1fba20173a506cf487483d5e3dd1289a initialized by task ('shuffle-transfer-1fba20173a506cf487483d5e3dd1289a', 24) executed on worker tcp://127.0.0.1:13845
# WARNING:distributed.shuffle._scheduler_plugin:Shuffle 1fba20173a506cf487483d5e3dd1289a deactivated due to stimulus 'task-finished-1736980693.9259634'

# %%
# Initial loading

from lsdb import read_hats


#obj_hats = read_hats(comcam_obj)
src_hats = read_hats(comcam_src, columns=["objectId", "coord_ra", "coord_dec", "band", "psfFlux", "psfFluxErr", "visit"])

src_hats
# Out:
# Dask NestedFrame Structure:
#                            objectId         coord_ra        coord_dec             band          psfFlux       psfFluxErr           visit
# npartitions=310
# 9007199254740992     int64[pyarrow]  double[pyarrow]  double[pyarrow]  string[pyarrow]  double[pyarrow]  double[pyarrow]  int64[pyarrow]
# 9570149208162304                ...              ...              ...              ...              ...              ...             ...
# ...                             ...              ...              ...              ...              ...              ...             ...
# 2540030189836959744             ...              ...              ...              ...              ...              ...             ...
# 2558044588346441728             ...              ...              ...              ...              ...              ...             ...
# Dask Name: nestedframe, 3 expressions
# Expr=MapPartitions(NestedFrame)

# %% [markdown]
# ## Dealing with missing MJD Information

# %%
# diasources have mjds tied to visits
from lsdb import read_hats
visit_mjds = read_hats(comcam_diasrc, columns=["visit", "midpointMjdTai"])
visit_lookup = visit_mjds._ddf.set_index("visit").drop_duplicates() # create a visit/mjd lookup table
visit_lookup.head(5)
# Out:
#                midpointMjdTai
# visit
# 2024110500210     60620.30587
# 2024110500230    60620.317381
# 2024110500247     60620.32962
# 2024110600158     60621.18728
# 2024110600164    60621.190339

# %%
# Generate a Forced Source Table with MJDs

# Index Forced Sources on and join to the visit lookup table
src_ddf = src_hats._ddf.set_index("visit")
src_mjd_ddf = src_ddf.join(visit_lookup)

# Reindex on objectId and save to parquet (this is no longer HATS)
src_mjd_ddf = src_mjd_ddf.set_index("objectId")
#src_mjd_ddf.to_parquet("/sdf/data/rubin/shared/lsdb_commissioning/forcedSource_50_with_mjd") # uncomment to save to disk

# %% [markdown]
# ## Loading & Nesting Forced Sources

# %%
# Load the Forced Source + MJD Table
import nested_dask as nd

src_mjd_ddf = nd.read_parquet("/sdf/data/rubin/shared/lsdb_commissioning/forcedSource_50_with_mjd", calculate_divisions=True)
src_nested = nd.NestedFrame.from_flat(src_mjd_ddf, base_columns=["coord_ra", "coord_dec"],
                                      nested_columns=["band", "psfFlux", "psfFluxErr", "midpointMjdTai"],
                                      name="lc")
src_nested
# Out:
# Dask NestedFrame Structure:
#                             coord_ra        coord_dec                                                                                               lc
# npartitions=310
# 199279885464633345   double[pyarrow]  double[pyarrow]  nested<band: [large_string], psfFlux: [double], psfFluxErr: [double], midpointMjdTai: [double]>
# 199548166301815239               ...              ...                                                                                              ...
# ...                              ...              ...                                                                                              ...
# 4708143974508930760              ...              ...                                                                                              ...
# 4708236333485657710              ...              ...                                                                                              ...
# Dask Name: lambda, 3 expressions
# Expr=MapPartitions(lambda)

# %%
# Grab columns from the Object Catalog
from lsdb import read_hats
obj_ddf = read_hats(comcam_obj, columns=["objectId", "g_psfFlux", "r_psfFlux"])._ddf.set_index("objectId")

# LSDB joins with non-catalogs don't really work, so cheating by using native Dask/Nested-Dask
src_nested = src_nested.join(obj_ddf).dropna(subset=["g_psfFlux", "r_psfFlux"])
src_nested
# Out:
# Dask NestedFrame Structure:
#                             coord_ra        coord_dec                                                                                               lc        g_psfFlux        r_psfFlux
# npartitions=393
# 199279885464633345   double[pyarrow]  double[pyarrow]  nested<band: [large_string], psfFlux: [double], psfFluxErr: [double], midpointMjdTai: [double]>  double[pyarrow]  double[pyarrow]
# 199389836627411188               ...              ...                                                                                              ...              ...              ...
# ...                              ...              ...                                                                                              ...              ...              ...
# 4708143974508930760              ...              ...                                                                                              ...              ...              ...
# 4708236333485657710              ...              ...                                                                                              ...              ...              ...
# Dask Name: lambda, 9 expressions
# Expr=MapPartitions(lambda)

# %%
# Pre-Processing

# Use just r-band data
src_nested = src_nested.query("lc.band == 'r'").dropna(subset="lc")

# Remove any high-error measurements
src_nested = src_nested.query("lc.psfFluxErr < 500").dropna(subset="lc")

# Count the length of the lightcurves, and add a length filter
from nested_dask.utils import count_nested
src_nested = count_nested(src_nested, "lc", join=True).query("n_lc > 200")

# %%
# g-r cut (proxy for B-V)
import astropy.units as u
import numpy as np

# Define a g_r calculation function
def g_r(g_flux, r_flux):
    """calculates g-r from g_flux and r_flux"""
    g_mag = u.nJy.to(u.ABmag, g_flux)
    r_mag = u.nJy.to(u.ABmag, r_flux)
    return {"gr": g_mag-r_mag}

# Apply the function, and return as a new column
src_nested = src_nested.query("g_psfFlux > 0 and r_psfFlux > 0")
g_r = src_nested.reduce(g_r, "g_psfFlux", "r_psfFlux", meta={"gr": np.float32})
src_nested = src_nested.join(g_r)

# Then cut on g-r
src_nested = src_nested.query("gr > -0.1 and gr < 0.5")
src_nested
# Out:
# Dask NestedFrame Structure:
#                             coord_ra        coord_dec                                                                                               lc        g_psfFlux        r_psfFlux     n_lc       gr
# npartitions=393
# 199279885464633345   double[pyarrow]  double[pyarrow]  nested<band: [large_string], psfFlux: [double], psfFluxErr: [double], midpointMjdTai: [double]>  double[pyarrow]  double[pyarrow]  float64  float32
# 199389836627411188               ...              ...                                                                                              ...              ...              ...      ...      ...
# ...                              ...              ...                                                                                              ...              ...              ...      ...      ...
# 4708143974508930760              ...              ...                                                                                              ...              ...              ...      ...      ...
# 4708236333485657710              ...              ...                                                                                              ...              ...              ...      ...      ...
# Dask Name: lambda, 19 expressions
# Expr=MapPartitions(lambda)

# %%
len(src_nested) # number of lightcurves after the above cuts
# Out:
# 30534

# %% [markdown]
# ## Running Lomb-Scargle
# Use Lightcurve package

# %%
import light_curve as licu
import numpy as np

extractor = licu.Extractor(
    licu.Periodogram(
        peaks=1,
        #nyquist=0.5, # this seems to hang the run
        max_freq_factor=30, # Currently 1.0 for fast runs, will raise for more interesting graphs later
        fast=False,
    ),  # Would give two features: peak period and signa-to-noise ratio of the peak
)


# light-curve requires all arrays to be the same dtype.
# It also requires the time array to be ordered and to have no duplicates.
def extract_features(mjd, mag, **kwargs):
    # We offset date, so we still would have <1 second precision
    t = np.asarray(mjd - 60000, dtype=np.float64)

    # Filter any infinite mags (fluxes here)
    t = t[np.isfinite(mag)]
    mag = mag[np.isfinite(mag)]

    _, sort_index = np.unique(t, return_index=True)
    features = extractor(
        t[sort_index],
        mag[sort_index],
        **kwargs,
    )
    # Return the features as a dictionary
    return dict(zip(extractor.names, features))


features = src_nested.reduce(
    extract_features,
    "lc.midpointMjdTai",
    "lc.psfFlux",
    meta={name: np.float32 for name in extractor.names},
)

src_nested = src_nested.join(features)

# %%
src_nested.head(5, npartitions=-1)
# Out:
#                       coord_ra  coord_dec  \
# objectId
# 2132568772769219544  53.028352 -28.307962
# 2132568772769219727   53.03881  -28.30068
# 2132568772769219768  53.063539 -28.298963
# 2132568772769219866  53.064233 -28.294273
# 2132568772769219920  53.064821 -28.292499
#
#                                                                     lc  \
# objectId
# 2132568772769219544      band     psfFlux  psfFluxErr  midpointMjdT...
# 2132568772769219727      band     psfFlux  psfFluxErr  midpointMjdT...
# 2132568772769219768      band     psfFlux  psfFluxErr  midpointMjdT...
# 2132568772769219866      band      psfFlux  psfFluxErr  midpointMjd...
# 2132568772769219920      band     psfFlux  psfFluxErr  midpointMjdT...
#
#                       g_psfFlux   r_psfFlux  n_lc        gr  period_0  \
# objectId
# 2132568772769219544  239.065489  363.600509   201  0.455269  0.020909
# 2132568772769219727  112.579908  119.026103   201  0.060453  0.019996
# 2132568772769219768   91.710765   85.149336   202 -0.080598  0.015688
# 2132568772769219866  592.610002  727.641239   202  0.222871  0.019690
# 2132568772769219920  177.399504  178.411368   202  0.006175  0.069963
#
#                      period_s_to_n_0
# objectId
# 2132568772769219544         8.404782
# 2132568772769219727         7.262893
# 2132568772769219768         8.522769
# 2132568772769219866         8.593285
# 2132568772769219920         7.436450

# %% [markdown]
# ## RRLyrae Candidate Selection
# * Have periods of ~0.3–0.6 days

# %%
# %%time
# Look for periods around half a day, select for high S/N
src_nested_rrcand = src_nested.query("period_0 > 0.3 and period_0 < 0.6").query("period_s_to_n_0 > 10")
# Out:
# CPU times: user 10.2 ms, sys: 3.58 ms, total: 13.8 ms
# Wall time: 13.1 ms

# %%
len(src_nested_rrcand)
# Out:
# 17

# %% [markdown]
# ## Plotting a few Phase-Folded Candidates

# %%
cand_subset = src_nested_rrcand.head(1000, npartitions=-1)
cand_subset = cand_subset.sort_values(by="period_s_to_n_0", ascending=False)

# %%
cand_subset
# Out:
#                       coord_ra  coord_dec  \
# objectId
# 2133039363745925051  53.252511 -28.186259
# 2226748540758018644  53.243931 -28.191208
# 2226796919269630761  52.987749 -28.195892
# 2226792521223123861  53.099912 -28.114481
# 2226796919269640418  53.090893 -28.019704
# 2226796919269630778  52.990574 -28.196002
# 2133039363745925068  53.255037  -28.18484
# 2226796919269630775  52.989952 -28.196357
# 2133039363745925055  53.253173 -28.185938
# 2226748540758015890  53.147652  -28.24261
# 2226792521223127508  53.214483 -28.016424
# 2226840899734733893  52.919415 -27.986886
# 2226840899734745319  52.919415 -27.986886
# 2133039363745925066  53.254245  -28.18524
# 2226792521223127555  53.214795 -28.013924
# 2226840899734744775  52.972157  -27.99292
# 2226796919269638553  52.946834 -28.052638
#
#                                                                     lc  \
# objectId
# 2133039363745925051      band      psfFlux  psfFluxErr  midpointMjd...
# 2226748540758018644      band      psfFlux  psfFluxErr  midpointMjd...
# 2226796919269630761      band     psfFlux  psfFluxErr  midpointMjdT...
# 2226792521223123861      band     psfFlux  psfFluxErr  midpointMjdT...
# 2226796919269640418      band     psfFlux  psfFluxErr  midpointMjdT...
# 2226796919269630778      band      psfFlux  psfFluxErr  midpointMjd...
# 2133039363745925068      band     psfFlux  psfFluxErr  midpointMjdT...
# 2226796919269630775      band      psfFlux  psfFluxErr  midpointMjd...
# 2133039363745925055      band      psfFlux  psfFluxErr  midpointMjd...
# 2226748540758015890      band      psfFlux  psfFluxErr  midpointMjd...
# 2226792521223127508      band      psfFlux  psfFluxErr  midpointMjd...
# 2226840899734733893      band     psfFlux  psfFluxErr  midpointMjdT...
# 2226840899734745319      band     psfFlux  psfFluxErr  midpointMjdT...
# 2133039363745925066      band      psfFlux  psfFluxErr  midpointMjd...
# 2226792521223127555      band      psfFlux  psfFluxErr  midpointMjd...
# 2226840899734744775      band      psfFlux  psfFluxErr  midpointMjd...
# 2226796919269638553      band     psfFlux  psfFluxErr  midpointMjdT...
#
#                       g_psfFlux   r_psfFlux  n_lc        gr  period_0  \
# objectId
# 2133039363745925051   450.61279  538.127402   207  0.192704  0.333295
# 2226748540758018644  473.048957  565.581496   201  0.193973  0.332986
# 2226796919269630761  221.541191   248.93723   202  0.126588  0.332268
# 2226792521223123861  173.244471  195.768252   210  0.132707  0.304277
# 2226796919269640418   77.524048   97.190093   204  0.245464  0.499710
# 2226796919269630778  166.874106   241.21828   208  0.400053  0.499663
# 2133039363745925068  169.345308  209.725269   204  0.232194  0.333318
# 2226796919269630775  242.633376  308.182304   207  0.259643  0.333295
# 2133039363745925055  255.804666   364.99154   208  0.385936  0.332930
# 2226748540758015890  198.061017  203.369951   209  0.028719  0.332212
# 2226792521223127508  615.074148  830.371177   222  0.325862  0.499511
# 2226840899734733893  278.427431   307.76691   206  0.108775  0.391571
# 2226840899734745319  278.427431   307.76691   206  0.108775  0.391571
# 2133039363745925066  135.375342  150.793279   204  0.117106  0.332962
# 2226792521223127555  278.873532  369.524891   222  0.305591  0.333543
# 2226840899734744775  426.290583  531.785541   202  0.240077  0.529481
# 2226796919269638553  214.066632  218.634054   209  0.022922  0.364073
#
#                      period_s_to_n_0
# objectId
# 2133039363745925051        12.683511
# 2226748540758018644        12.525687
# 2226796919269630761        12.426941
# 2226792521223123861        12.313243
# 2226796919269640418        11.744122
# 2226796919269630778        11.583959
# 2133039363745925068        11.506978
# 2226796919269630775        11.295020
# 2133039363745925055        10.839012
# 2226748540758015890        10.821558
# 2226792521223127508        10.810661
# 2226840899734733893        10.662080
# 2226840899734745319        10.662080
# 2133039363745925066        10.572888
# 2226792521223127555        10.434784
# 2226840899734744775        10.125546
# 2226796919269638553        10.018188

# %%
import matplotlib.pyplot as plt

#cand = cand_subset.iloc[1]
cand = cand_subset.loc[2226796919269630775]
phase = cand.lc["midpointMjdTai"] % cand["period_0"] / cand["period_0"]
plt.errorbar(phase,cand.lc["psfFlux"],cand.lc["psfFluxErr"], fmt="o")
plt.title(f"ObjectId: {cand.name}, Period: {np.round(cand['period_0'],6)}")
plt.ylabel("psfFlux")
plt.xlabel("Phase")
print(cand.name)
# Out:
# 2226796919269630775

# %% [markdown]
# ### Potentially Interesting Candidates
# 2226748540758018644, 2226840899734749849, 2226796919269630775
