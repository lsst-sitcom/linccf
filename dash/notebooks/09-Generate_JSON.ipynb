# %%
CONFIG_PATH = "../example_config.toml"

# %%
from linccf_dash.config import load_config
from linccf_dash.stages.generate_json import run_generate_json

cfg = load_config(CONFIG_PATH)
run_generate_json(cfg)
